# %%
from tatlin_plotter import json_file_reader, preprocess_history, plot_history

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
filepath = "/home/kenenbek/tmp/compare_tatlin/data/"
w_filename_old = filepath + "write_old_output.txt"
w_filename_new = filepath + "write_new_output.txt"
r_filename_old = filepath + "read_old_output.txt"
r_filename_new = filepath + "read_new_output.txt"

# %%
w_history_old = preprocess_history(json_file_reader(w_filename_old))
w_history_new = preprocess_history(json_file_reader(w_filename_new))
r_history_old = preprocess_history(json_file_reader(r_filename_old))
r_history_new = preprocess_history(json_file_reader(r_filename_new))

# %%
plot_history(w_history_old, w_history_new, r_history_old, r_history_new)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-9d7ea8af86ec> in <module>()
# ----> 1 plot_history(w_history_old, w_history_new, r_history_old, r_history_new)
#
# ~/tmp/compare_tatlin/tatlin_plotter.py in plot_history(w_history_old, w_history_new, r_history_old, r_history_new)
#      52         r_data_new = [h['ambience'][name] for h in r_history_new]
#      53
# ---> 54         _subplotter(w_data_old, w_data_new, r_data_old, r_data_new, name)
#      55
#      56     return
#
# ~/tmp/compare_tatlin/tatlin_plotter.py in _subplotter(w_data_old, w_data_new, r_data_old, r_data_new, name)
#      25 def _subplotter(w_data_old, w_data_new, r_data_old, r_data_new, name):
#      26     fig, ax_list = plt.subplots(2, 2, figsize=(15,6))
# ---> 27     fig.style
#      28
#      29     ax_list[0, 0].plot(w_data_old, lw=3, c='b')
#
# ...

# %%
from matplotlib import pyplot as plt 
# %matplotlib inline
with plt.style.context("seaborn-white"):
    plt.rcParams["axes.grid"] = True
    fig, ax = plt.subplots()
    plt.plot([0, 1, 2], [1, 1, 1])
    plt.show()
